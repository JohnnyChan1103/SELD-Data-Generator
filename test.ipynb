# %%
from data_generator.db_config import DBConfig
import pickle
import numpy as np

# %%
db_config_path = 'db_config_FSD50K.obj'
with open(db_config_path, 'rb') as f:
    db_config = pickle.load(f)
print(db_config._sample_list['class'])
print(len(db_config._sample_list['class']))
# Out:
# [  0   0   0 ... 179 179 179]
# 36293
